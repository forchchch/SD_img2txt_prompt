# %%
import os
from PIL import Image
in_root = "/DATA/DATANAS1/chenhong/diffusion_research/lora/disen_dreambooth/output_dreambooth/pix2pix"
out_root = "/DATA/DATANAS1/zhangyip/imgs"
subject_list = ["backpack","can", "cat", "cat2", "colorful_sneaker", "dog7", "duck_toy", "grey_sloth_plushie"]

# %%
subject = subject_list[7]
out_pic_name = "Pix2Pix.jpg"
#######################
# subfolder_name = "global0.01_disen0.001_step800/0.0"
subfolder_name = ""
pic_name = "211.jpg"
#######################
in_path = os.path.join(in_root, subject, subfolder_name ,pic_name)
print(in_path)
image  = Image.open( in_path )
#######################
prompt_order = 3
#######################
out_path = os.path.join(out_root, subject, str(prompt_order), out_pic_name)
print(out_path)
image.save(out_path)
image
# Out:
# /DATA/DATANAS1/chenhong/diffusion_research/lora/disen_dreambooth/output_dreambooth/pix2pix/grey_sloth_plushie/211.jpg
# /DATA/DATANAS1/zhangyip/imgs/grey_sloth_plushie/3/Pix2Pix.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
